# %% [markdown]
# ## LLM Priors Assessments
#
# ### Define functions to generate descriptions and priors for synthetic datasets

# %%
from pathlib import Path

import pandas as pd
import pyagrum as gum
from tqdm.asyncio import tqdm

from priors.llm import (
    GraphDescriptionBase,
    extract,
    parse_graph_description,
    parse_priors,
)
from priors.prompt import prepare_graph_description, prepare_priors

async def generate_graph_description(
    causal_graph: gum.BayesNet,
    model: str = "gemini-2.5-flash",
) -> GraphDescriptionBase:
    graph_prompt = prepare_graph_description(causal_graph)
    graph_description_raw = (
        (await extract(graph_prompt, None, model=model)).choices[0].message.content
    )
    assert graph_description_raw is not None, "Failed to obtain graph description"

    return await parse_graph_description(
        graph_description_raw, parse_method="llm", valid_vars=causal_graph.names()
    )


async def enrich_graph(
    causal_graph: gum.BayesNet,
    model: str = "gemini-2.5-flash",
    save_dir: str | Path | None = None,
):
    graph_description = await generate_graph_description(causal_graph, model=model)
    for name, description in graph_description.variable_descriptions.items():
        causal_graph.variableFromName(name).setDescription(description)
    causal_graph.setProperty("name", graph_description.title)  # pyagrum ignores the name property when loading from BIFXML
    if save_dir is not None:
        if isinstance(save_dir, str):
            save_dir = Path(save_dir)
        save_dir.mkdir(parents=True, exist_ok=True)
        save_path = save_dir / f"{graph_description.identifier}.bifxml"
        causal_graph.saveBIFXML(str(save_path))

    return graph_description


async def generate_priors(
    bn: gum.BayesNet,
    variable_descriptions: dict[str, str] | None = None,
    prior_model: str = "gemini-2.5-flash",
    parse_model: str = "gemini-2.5-flash-lite",
) -> dict:
    priors_prompt = prepare_priors(bn, descriptions=variable_descriptions)
    priors_raw = (
        (await extract(priors_prompt, None, model=prior_model)).choices[0].message.content
    )
    assert priors_raw is not None, "Failed to obtain priors"

    priors = await parse_priors(
        prior_response=priors_raw, model=parse_model, valid_vars=bn.names()
    )
    edges_to_remove = {frozenset(pair) for pair in priors}
    true_edges = {
        frozenset((bn.variable(id1).name(), bn.variable(id2).name()))
        for id1, id2 in bn.arcs()
    }

    # Positive represents the number of edges classified as forbidden (edges_to_remove)
    false_positive = len(edges_to_remove & true_edges)
    true_positive = len(edges_to_remove) - false_positive

    return {
        "priors": priors,
        "TP": true_positive,
        "FP": false_positive,
    }


async def evaluate_priors(bif_paths: list[str | Path], prior_model: str, parse_model: str = None, exclude_descriptions: bool = False) -> pd.DataFrame:
    if parse_model is None:
        parse_model = prior_model
    prior_results = []
    prior_tasks = []
    for bif_path in bif_paths:
        if isinstance(bif_path, str):
            bif_path = Path(bif_path)
        bn = gum.loadBN(str(bif_path))
        variable_descriptions = {
            name: bn.variable(name).description() for name in bn.names()
        }
        if exclude_descriptions or not any(variable_descriptions.values()):
            variable_descriptions = None
        prior_results.append(
            {
                "bn": bn,
                "title": bn.propertyWithDefault("name", "no_name"),
                "filename": bif_path.stem,
                "num_nodes": bn.size(),
                "num_edges": len(bn.arcs()),
                "variable_descriptions": variable_descriptions,
            }
        )
        prior_tasks.append(
            generate_priors(
                bn=bn,
                variable_descriptions=variable_descriptions,
                prior_model=prior_model,
                parse_model=parse_model,
            )
        )
    prior_res = await tqdm.gather(*prior_tasks)
    for res_dict, prior_res in zip(prior_results, prior_res):
        res_dict.update(prior_res)
    df = pd.DataFrame(prior_results)

    beta = 0.2
    df["TN"] = df["num_edges"] - df["FP"]
    df["FN"] = df["num_nodes"] * (df["num_nodes"] - 1) // 2 - df["num_edges"] - df["TP"]
    df["Precision"] = df["TP"] / (df["TP"] + df["FP"])
    df["Recall"] = df["TP"] / (df["TP"] + df["FN"])
    df["F-beta"] = (
        (1 + beta**2)
        * df["Precision"]
        * df["Recall"]
        / (beta**2 * df["Precision"] + df["Recall"])
    )

    return df

# %% [markdown]
# ### Define experiment and helper function to evaluate the precision of LLM removed edges as causal priors

# %%
async def run_experiments(
    dataset_paths,
    n_runs=5,
    exclude_descriptions=True,
    prior_model="gemini-2.5-flash",
    parse_model=None,
):
    """
    Run multiple experiments and return combined results.

    Usage:
        results_no_desc = await run_experiments(bnlearn_small_datasets, n_runs=5, exclude_descriptions=True)
        results_with_desc = await run_experiments(bnlearn_small_datasets, n_runs=5, exclude_descriptions=False)
    """
    all_results = []

    for run_id in range(n_runs):
        print(f"Run {run_id + 1}/{n_runs}")
        df = await evaluate_priors(
            bif_paths=dataset_paths,
            prior_model=prior_model,
            parse_model=parse_model,
            exclude_descriptions=exclude_descriptions,
        )
        df["run_id"] = run_id
        all_results.append(df)

    return pd.concat(all_results, ignore_index=True)


def get_summary(df, metrics=["Precision", "Recall", "F-beta"]):
    """
    Get summary statistics for each dataset.

    Usage:
        summary = get_summary(results_no_desc)
    """
    summary_data = []

    for dataset in df["filename"].unique():
        dataset_df = df[df["filename"] == dataset]

        for metric in metrics:
            values = dataset_df[metric].dropna()

            if len(values) > 0:
                summary_data.append(
                    {
                        "Dataset": dataset,
                        "Metric": metric,
                        "Mean": values.mean(),
                        "Std": values.std(),
                        "Min": values.min(),
                        "Max": values.max(),
                        "Runs": len(values),
                    }
                )

    return pd.DataFrame(summary_data)


def show_report(df, metrics=["Precision", "Recall", "F-beta"]):
    """
    Get summary statistics for each dataset.

    Usage:
        summary = show_report(results_no_desc)
    """
    groups = df.groupby(["filename", "with_desc"])
    meta = groups.agg(
        {
            "num_nodes": "first",
            "num_edges": "first",
        }
    )
    meta["repeats"] = groups.size()
    meta.columns = pd.MultiIndex.from_product([["meta"], meta.columns])
    index = (
        groups["num_nodes"]
        .first()
        .reset_index()
        .sort_values(["num_nodes", "filename", "with_desc"])
        .set_index(["filename", "with_desc"])
        .index
    )
    summary = pd.concat([meta, groups[metrics].agg(["mean", "std"])], axis=1)
    return summary.loc[index]

# %% [markdown]
# ### Experiment Configurations

# %%
repeats = 10
prior_model = "gemini-2.5-flash"
parse_model = "gemini-2.5-flash-lite"

# %% [markdown]
# ### Run experiments on bnlearn datasets with/without variable descriptions

# %%
bnlearn_small_datasets = list(Path("priors/datasets/bnlearn/").glob("*.bifxml"))

bnlearn_results_no_desc = await run_experiments(
    bnlearn_small_datasets,
    n_runs=repeats,
    exclude_descriptions=True,
    prior_model=prior_model,
    parse_model=parse_model,
)
# Save complete results for the record
bnlearn_results_no_desc.drop(columns="bn").to_json("results/2025/llm/bnlearn_no_desc.json", orient="records", indent=4)
get_summary(bnlearn_results_no_desc)
# Out:
#        Dataset     Metric      Mean       Std       Min       Max  Runs
# 0       survey  Precision  0.641212  0.129287  0.545455  1.000000    10
# 1       survey     Recall  0.744444  0.291865  0.333333  1.000000    10
# 2       survey     F-beta  0.636324  0.105949  0.549296  0.928571    10
# 3       cancer  Precision  1.000000  0.000000  1.000000  1.000000    10
# 4       cancer     Recall  0.533333  0.172133  0.333333  0.833333    10
# 5       cancer     F-beta  0.961965  0.021304  0.928571  0.992366    10
# 6        sachs  Precision  0.791352  0.030685  0.738095  0.846154    10
# 7        sachs     Recall  0.710526  0.213069  0.289474  0.947368    10
# 8        sachs     F-beta  0.782865  0.025311  0.740809  0.809969    10
# 9         asia  Precision  0.959048  0.065991  0.857143  1.000000    10
# 10        asia     Recall  0.820000  0.129529  0.600000  0.900000    10
# 11        asia     F-beta  0.952485  0.069737  0.843243  0.995745    10
# 12  earthquake  Precision  1.000000  0.000000  1.000000  1.000000    10
# 13  earthquake     Recall  0.833333  0.000000  0.833333  0.833333    10
# 14  earthquake     F-beta  0.992366  0.000000  0.992366  0.992366    10

# %%
bnlearn_results_with_desc = await run_experiments(
    bnlearn_small_datasets,
    n_runs=repeats,
    exclude_descriptions=False,
    prior_model=prior_model,
    parse_model=parse_model,
)
# Save complete results for the record
bnlearn_results_with_desc.drop(columns="bn").to_json("results/2025/llm/bnlearn_with_desc.json", orient="records", indent=4)
get_summary(bnlearn_results_with_desc)
# Out:
#        Dataset     Metric      Mean       Std       Min       Max  Runs
# 0       survey  Precision  0.913333  0.114342  0.750000  1.000000    10
# 1       survey     Recall  0.300000  0.139074  0.111111  0.555556    10
# 2       survey     F-beta  0.817419  0.082249  0.715596  0.928571    10
# 3       cancer  Precision  1.000000  0.000000  1.000000  1.000000    10
# 4       cancer     Recall  0.583333  0.211549  0.166667  0.833333    10
# 5       cancer     F-beta  0.961176  0.045130  0.838710  0.992366    10
# 6        sachs  Precision  0.753366  0.034493  0.734694  0.818182    10
# 7        sachs     Recall  0.942105  0.016644  0.894737  0.947368    10
# 8        sachs     F-beta  0.759171  0.033694  0.741093  0.822496    10
# 9         asia  Precision  0.893423  0.050324  0.833333  1.000000    10
# 10        asia     Recall  0.700000  0.113039  0.500000  0.900000    10
# 11        asia     F-beta  0.883523  0.053928  0.812500  0.995745    10
# 12  earthquake  Precision  1.000000  0.000000  1.000000  1.000000    10
# 13  earthquake     Recall  0.833333  0.000000  0.833333  0.833333    10
# 14  earthquake     F-beta  0.992366  0.000000  0.992366  0.992366    10

# %%
# bnlearn_results_no_desc = pd.read_json("results/2025/llm/bnlearn_no_desc.json")
# bnlearn_results_with_desc = pd.read_json("results/2025/llm/bnlearn_with_desc.json")
bnlearn_results_no_desc["with_desc"] = False
bnlearn_results_with_desc["with_desc"] = True

show_report(pd.concat([bnlearn_results_no_desc, bnlearn_results_with_desc], ignore_index=True))
# Out:
#                           meta                   Precision            \
#                      num_nodes num_edges repeats      mean       std
# filename   with_desc
# cancer     False             5         4      10  1.000000  0.000000
#            True              5         4      10  1.000000  0.000000
# earthquake False             5         4      10  1.000000  0.000000
#            True              5         4      10  1.000000  0.000000
# survey     False             6         6      10  0.641212  0.129287
#            True              6         6      10  0.913333  0.114342
# asia       False             8         8      10  0.959048  0.065991
#            True              8         8      10  0.893423  0.050324
# sachs      False            11        17      10  0.791352  0.030685
#            True             11        17      10  0.753366  0.034493
#
#                         Recall              F-beta
#                           mean       std      mean       std
# filename   with_desc
# cancer     False      0.533333  0.172133  0.961965  0.021304
#            True       0.583333  0.211549  0.961176  0.045130
# earthquake False      0.833333  0.000000  0.992366  0.000000
#            True       0.833333  0.000000  0.992366  0.000000
# survey     False      0.744444  0.291865  0.636324  0.105949
#            True       0.300000  0.139074  0.817419  0.082249
# asia       False      0.820000  0.129529  0.952485  0.069737
#            True       0.700000  0.113039  0.883523  0.053928
# sachs      False      0.710526  0.213069  0.782865  0.025311
#            True       0.942105  0.016644  0.759171  0.033694

# %% [markdown]
# Save the best prior record for each dataset for combining with CausalABA.
#
# Best is defined as the highest precision, and in case of ties, the highest F-beta (Recall).

# %%
bnlearn_all_results = pd.concat(
    [bnlearn_results_no_desc, bnlearn_results_with_desc], ignore_index=True
).drop(columns="bn")
bnlearn_best_results = (
    bnlearn_all_results.sort_values(
        by=["filename", "Precision", "F-beta"], ascending=[True, False, False]
    )
    .groupby("filename", as_index=False)
    .first()
)
bnlearn_best_results.to_json(
    "priors/datasets/bnlearn/prior_df.json", orient="records", indent=4
)
bnlearn_best_results
# Out:
#      filename       title  num_nodes  num_edges  \
# 0        asia        asia          8          8
# 1      cancer      cancer          5          4
# 2  earthquake  earthquake          5          4
# 3       sachs       sachs         11         17
# 4      survey      survey          6          6
#
#                                variable_descriptions  \
# 0  {'smoke': 'smoking: whether or not the patient...
# 1  {'Cancer': 'Cancer: Indicates whether the pers...
# 2  {'Earthquake': 'The occurrence of seismic acti...
# 3  {'PKA': 'PKA (Protein Kinase A): cAMP-dependen...
# 4  {'A': 'Age: the age, recorded as young (young)...
#
#                                               priors  TP  FP  TN  FN  \
# 0  {(bronc, tub), (xray, bronc), (smoke, asia), (...  18   0   8   2
# 1  {(Xray, Dyspnoea), (Dyspnoea, Smoker), (Pollut...   5   0   4   1
# 2  {(Earthquake, JohnCalls), (Burglary, JohnCalls...   5   0   4   1
# 3  {(Jnk, Akt), (PKA, P38), (Akt, P38), (Plcg, P3...  11   2  15  27
# 4                           {(A, S), (A, R), (A, O)}   3   0   6   6
#
#    Precision    Recall    F-beta  run_id
# 0   1.000000  0.900000  0.995745       0
# 1   1.000000  0.833333  0.992366       2
# 2   1.000000  0.833333  0.992366       0
# 3   0.846154  0.289474  0.787879       1
# 4   1.000000  0.333333  0.928571       3

# %% [markdown]
# ### Run experiments on randomly generated datasets with/without variable descriptions

# %%
synthetic_datasets = list(Path("priors/datasets/random_graphs/heuristic_by_semantic").glob("*.bifxml"))

synthetic_results_no_desc = await run_experiments(
    synthetic_datasets,
    n_runs=repeats,
    exclude_descriptions=True,
    prior_model=prior_model,
    parse_model=parse_model,
)
# Save complete results for the record
synthetic_results_no_desc.drop(columns="bn").to_json("results/2025/llm/synthetic_no_desc.json", orient="records", indent=4)
get_summary(synthetic_results_no_desc)
# Out:
# Run 1/10
# 100%|██████████| 7/7 [02:35<00:00, 22.28s/it]
# Run 2/10
# 100%|██████████| 7/7 [02:54<00:00, 24.96s/it]
# Run 3/10
# 100%|██████████| 7/7 [04:51<00:00, 41.69s/it]
# Run 4/10
# 100%|██████████| 7/7 [02:56<00:00, 25.23s/it]
# Run 5/10
# 100%|██████████| 7/7 [01:52<00:00, 16.11s/it]
# Run 6/10
# 100%|██████████| 7/7 [01:46<00:00, 15.16s/it]
# Run 7/10
# 100%|██████████| 7/7 [04:42<00:00, 40.39s/it]
# Run 8/10
# 100%|██████████| 7/7 [01:39<00:00, 14.23s/it]
# Run 9/10
# 100%|██████████| 7/7 [02:44<00:00, 23.51s/it]
# Run 10/10
# 100%|██████████| 7/7 [02:23<00:00, 20.49s/it]
#                                               Dataset     Metric      Mean  \
# 0        factors_influencing_well_being_and_resources  Precision  0.947457
# 1        factors_influencing_well_being_and_resources     Recall  0.232143
# 2        factors_influencing_well_being_and_resources     F-beta  0.819527
# 3         pharmacological_and_cardiac_health_dynamics  Precision  0.938095
# 4         pharmacological_and_cardiac_health_dynamics     Recall  0.522222
# 5         pharmacological_and_cardiac_health_dynamics     F-beta  0.903653
# 6          interacting_health_conditions_and_outcomes  Precision  0.951453
# 7          interacting_health_conditions_and_outcomes     Recall  0.333333
# 8          interacting_health_conditions_and_outcomes     F-beta  0.794582
# 9   clinical_variables_in_cardiovascular_and_gastr...  Precision  0.950000
# 10  clinical_variables_in_cardiovascular_and_gastr...     Recall  0.316667
# 11  clinical_variables_in_cardiovascular_and_gastr...     F-beta  0.863068
# 12  clinical_pathways_in_cardiac_and_abdominal_health  Precision  0.964413
# 13  clinical_pathways_in_cardiac_and_abdominal_health     Recall  0.435714
# 14  clinical_pathways_in_cardiac_and_abdominal_health     F-beta  0.856224
# 15  interconnected_health_and_socio_economic_outcomes  Precision  0.899115
# 16  interconnected_health_and_socio_economic_outcomes     Recall  0.564706
# 17  interconnected_health_and_socio_economic_outcomes     F-beta  0.871558
# 18                    medical_conditions_and_outcomes  Precision  0.930032
# 19                    medical_conditions_and_outcomes     Recall  0.271429
# 20                    medical_conditions_and_outcomes     F-beta  0.812083
#
#          Std       Min       Max  Runs
# 0   0.070291  0.833333  1.000000    10
# 1   0.111993  0.107143  0.428571    10
# 2   0.034739  0.757282  0.876404    10
# 3   0.112351  0.666667  1.000000    10
# 4   0.181821  0.222222  0.777778    10
# 5   0.112139  0.619048  0.989130    10
# 6   0.046112  0.870968  1.000000    10
# 7   0.211338  0.022222  0.600000    10
# 8   0.182864  0.371429  0.907383    10
# 9   0.105409  0.750000  1.000000    10
# 10  0.122977  0.166667  0.500000    10
# 11  0.078601  0.735849  0.928571    10
# 12  0.046881  0.888889  1.000000    10
# 13  0.302015  0.071429  0.857143    10
# 14  0.106886  0.666667  0.935252    10
# 15  0.026291  0.857143  0.952381    10
# 16  0.179602  0.176471  0.823529    10
# 17  0.049410  0.746411  0.930233    10
# 18  0.095822  0.750000  1.000000    10
# 19  0.158810  0.095238  0.571429    10
# 20  0.091294  0.644628  0.941176    10

# %%
synthetic_results_with_desc = await run_experiments(
    synthetic_datasets,
    n_runs=repeats,
    exclude_descriptions=False,
    prior_model=prior_model,
    parse_model=parse_model,
)
# Save complete results for the record
synthetic_results_with_desc.drop(columns="bn").to_json("results/2025/llm/synthetic_with_desc.json", orient="records", indent=4)
get_summary(synthetic_results_with_desc)
# Out:
# Run 1/10
# 100%|██████████| 7/7 [02:45<00:00, 23.68s/it]
# Run 2/10
# 100%|██████████| 7/7 [02:36<00:00, 22.34s/it]
# Run 3/10
# 100%|██████████| 7/7 [01:52<00:00, 16.01s/it]
# Run 4/10
# 100%|██████████| 7/7 [02:14<00:00, 19.21s/it]
# Run 5/10
# 100%|██████████| 7/7 [01:46<00:00, 15.20s/it]
# Run 6/10
# 100%|██████████| 7/7 [02:09<00:00, 18.46s/it]
# Run 7/10
# 100%|██████████| 7/7 [02:34<00:00, 22.14s/it]
# Run 8/10
# 100%|██████████| 7/7 [01:56<00:00, 16.65s/it]
# Run 9/10
# 100%|██████████| 7/7 [03:59<00:00, 34.27s/it]
# Run 10/10
# 100%|██████████| 7/7 [04:41<00:00, 40.17s/it]
#                                               Dataset     Metric      Mean  \
# 0        factors_influencing_well_being_and_resources  Precision  0.836667
# 1        factors_influencing_well_being_and_resources     Recall  0.182143
# 2        factors_influencing_well_being_and_resources     F-beta  0.767150
# 3         pharmacological_and_cardiac_health_dynamics  Precision  0.983333
# 4         pharmacological_and_cardiac_health_dynamics     Recall  0.466667
# 5         pharmacological_and_cardiac_health_dynamics     F-beta  0.936548
# 6          interacting_health_conditions_and_outcomes  Precision  0.975942
# 7          interacting_health_conditions_and_outcomes     Recall  0.244444
# 8          interacting_health_conditions_and_outcomes     F-beta  0.833948
# 9   clinical_variables_in_cardiovascular_and_gastr...  Precision  1.000000
# 10  clinical_variables_in_cardiovascular_and_gastr...     Recall  0.316667
# 11  clinical_variables_in_cardiovascular_and_gastr...     F-beta  0.901322
# 12  clinical_pathways_in_cardiac_and_abdominal_health  Precision  0.992308
# 13  clinical_pathways_in_cardiac_and_abdominal_health     Recall  0.450000
# 14  clinical_pathways_in_cardiac_and_abdominal_health     F-beta  0.908354
# 15  interconnected_health_and_socio_economic_outcomes  Precision  0.901932
# 16  interconnected_health_and_socio_economic_outcomes     Recall  0.447059
# 17  interconnected_health_and_socio_economic_outcomes     F-beta  0.851919
# 18                    medical_conditions_and_outcomes  Precision  0.970909
# 19                    medical_conditions_and_outcomes     Recall  0.404762
# 20                    medical_conditions_and_outcomes     F-beta  0.919662
#
#          Std       Min       Max  Runs
# 0   0.314446  0.000000  1.000000    10
# 1   0.137241  0.000000  0.464286    10
# 2   0.161786  0.490566  0.924901     9
# 3   0.052705  0.833333  1.000000    10
# 4   0.126144  0.222222  0.666667    10
# 5   0.050264  0.817610  0.981132    10
# 6   0.044172  0.869565  1.000000    10
# 7   0.141712  0.066667  0.488889    10
# 8   0.081489  0.650000  0.922581    10
# 9   0.000000  1.000000  1.000000    10
# 10  0.165738  0.166667  0.666667    10
# 11  0.056589  0.838710  0.981132    10
# 12  0.024325  0.923077  1.000000    10
# 13  0.254328  0.071429  0.857143    10
# 14  0.098033  0.666667  0.984848    10
# 15  0.075410  0.750000  1.000000    10
# 16  0.180136  0.088235  0.647059    10
# 17  0.102129  0.582090  0.934132    10
# 18  0.046906  0.900000  1.000000    10
# 19  0.051434  0.333333  0.476190    10
# 20  0.036732  0.863469  0.959410    10

# %%
# synthetic_results_no_desc = pd.read_json("results/2025/llm/synthetic_no_desc.json")
# synthetic_results_with_desc = pd.read_json("results/2025/llm/synthetic_with_desc.json")
synthetic_results_no_desc["with_desc"] = False
synthetic_results_with_desc["with_desc"] = True

show_report(pd.concat([synthetic_results_no_desc, synthetic_results_with_desc], ignore_index=True))
# Out:
#                                                                   meta  \
#                                                              num_nodes
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False             5
#                                                    True              5
# pharmacological_and_cardiac_health_dynamics        False             6
#                                                    True              6
# clinical_pathways_in_cardiac_and_abdominal_health  False             7
#                                                    True              7
# medical_conditions_and_outcomes                    False             8
#                                                    True              8
# factors_influencing_well_being_and_resources       False             9
#                                                    True              9
# interconnected_health_and_socio_economic_outcomes  False            10
#                                                    True             10
# interacting_health_conditions_and_outcomes         False            11
#                                                    True             11
#
#                                                                         \
#                                                              num_edges
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False             4
#                                                    True              4
# pharmacological_and_cardiac_health_dynamics        False             6
#                                                    True              6
# clinical_pathways_in_cardiac_and_abdominal_health  False             7
#                                                    True              7
# medical_conditions_and_outcomes                    False             7
#                                                    True              7
# factors_influencing_well_being_and_resources       False             8
#                                                    True              8
# interconnected_health_and_socio_economic_outcomes  False            11
#                                                    True             11
# interacting_health_conditions_and_outcomes         False            10
#                                                    True             10
#
#                                                                       \
#                                                              repeats
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False          10
#                                                    True           10
# pharmacological_and_cardiac_health_dynamics        False          10
#                                                    True           10
# clinical_pathways_in_cardiac_and_abdominal_health  False          10
#                                                    True           10
# medical_conditions_and_outcomes                    False          10
#                                                    True           10
# factors_influencing_well_being_and_resources       False          10
#                                                    True           10
# interconnected_health_and_socio_economic_outcomes  False          10
#                                                    True           10
# interacting_health_conditions_and_outcomes         False          10
#                                                    True           10
#
#                                                              Precision  \
#                                                                   mean
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False      0.950000
#                                                    True       1.000000
# pharmacological_and_cardiac_health_dynamics        False      0.938095
#                                                    True       0.983333
# clinical_pathways_in_cardiac_and_abdominal_health  False      0.964413
#                                                    True       0.992308
# medical_conditions_and_outcomes                    False      0.930032
#                                                    True       0.970909
# factors_influencing_well_being_and_resources       False      0.947457
#                                                    True       0.836667
# interconnected_health_and_socio_economic_outcomes  False      0.899115
#                                                    True       0.901932
# interacting_health_conditions_and_outcomes         False      0.951453
#                                                    True       0.975942
#
#                                                                         \
#                                                                    std
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False      0.105409
#                                                    True       0.000000
# pharmacological_and_cardiac_health_dynamics        False      0.112351
#                                                    True       0.052705
# clinical_pathways_in_cardiac_and_abdominal_health  False      0.046881
#                                                    True       0.024325
# medical_conditions_and_outcomes                    False      0.095822
#                                                    True       0.046906
# factors_influencing_well_being_and_resources       False      0.070291
#                                                    True       0.314446
# interconnected_health_and_socio_economic_outcomes  False      0.026291
#                                                    True       0.075410
# interacting_health_conditions_and_outcomes         False      0.046112
#                                                    True       0.044172
#
#                                                                 Recall  \
#                                                                   mean
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False      0.316667
#                                                    True       0.316667
# pharmacological_and_cardiac_health_dynamics        False      0.522222
#                                                    True       0.466667
# clinical_pathways_in_cardiac_and_abdominal_health  False      0.435714
#                                                    True       0.450000
# medical_conditions_and_outcomes                    False      0.271429
#                                                    True       0.404762
# factors_influencing_well_being_and_resources       False      0.232143
#                                                    True       0.182143
# interconnected_health_and_socio_economic_outcomes  False      0.564706
#                                                    True       0.447059
# interacting_health_conditions_and_outcomes         False      0.333333
#                                                    True       0.244444
#
#                                                                         \
#                                                                    std
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False      0.122977
#                                                    True       0.165738
# pharmacological_and_cardiac_health_dynamics        False      0.181821
#                                                    True       0.126144
# clinical_pathways_in_cardiac_and_abdominal_health  False      0.302015
#                                                    True       0.254328
# medical_conditions_and_outcomes                    False      0.158810
#                                                    True       0.051434
# factors_influencing_well_being_and_resources       False      0.111993
#                                                    True       0.137241
# interconnected_health_and_socio_economic_outcomes  False      0.179602
#                                                    True       0.180136
# interacting_health_conditions_and_outcomes         False      0.211338
#                                                    True       0.141712
#
#                                                                 F-beta  \
#                                                                   mean
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False      0.863068
#                                                    True       0.901322
# pharmacological_and_cardiac_health_dynamics        False      0.903653
#                                                    True       0.936548
# clinical_pathways_in_cardiac_and_abdominal_health  False      0.856224
#                                                    True       0.908354
# medical_conditions_and_outcomes                    False      0.812083
#                                                    True       0.919662
# factors_influencing_well_being_and_resources       False      0.819527
#                                                    True       0.767150
# interconnected_health_and_socio_economic_outcomes  False      0.871558
#                                                    True       0.851919
# interacting_health_conditions_and_outcomes         False      0.794582
#                                                    True       0.833948
#
#
#                                                                    std
# filename                                           with_desc
# clinical_variables_in_cardiovascular_and_gastro... False      0.078601
#                                                    True       0.056589
# pharmacological_and_cardiac_health_dynamics        False      0.112139
#                                                    True       0.050264
# clinical_pathways_in_cardiac_and_abdominal_health  False      0.106886
#                                                    True       0.098033
# medical_conditions_and_outcomes                    False      0.091294
#                                                    True       0.036732
# factors_influencing_well_being_and_resources       False      0.034739
#                                                    True       0.161786
# interconnected_health_and_socio_economic_outcomes  False      0.049410
#                                                    True       0.102129
# interacting_health_conditions_and_outcomes         False      0.182864
#                                                    True       0.081489

# %% [markdown]
# Save the best prior record for each dataset for combining with CausalABA.
#
# Best is defined as the highest precision, and in case of ties, the highest F-beta (Recall).

# %%
synthetic_all_results = pd.concat(
    [synthetic_results_no_desc, synthetic_results_with_desc], ignore_index=True
).drop(columns="bn")
synthetic_best_results = (
    synthetic_all_results.sort_values(
        by=["filename", "Precision", "F-beta"], ascending=[True, False, False]
    )
    .groupby("filename", as_index=False)
    .first()
)
synthetic_best_results.to_json(
    "priors/datasets/random_graphs/prior_df.json", orient="records", indent=4
)
synthetic_best_results
# Out:
#                                             filename  \
# 0  clinical_pathways_in_cardiac_and_abdominal_health
# 1  clinical_variables_in_cardiovascular_and_gastr...
# 2       factors_influencing_well_being_and_resources
# 3         interacting_health_conditions_and_outcomes
# 4  interconnected_health_and_socio_economic_outcomes
# 5                    medical_conditions_and_outcomes
# 6        pharmacological_and_cardiac_health_dynamics
#
#                                                title  num_nodes  num_edges  \
# 0  clinical_pathways_in_cardiac_and_abdominal_health          7          7
# 1  clinical_variables_in_cardiovascular_and_gastr...          5          4
# 2       factors_influencing_well_being_and_resources          9          8
# 3         interacting_health_conditions_and_outcomes         11         10
# 4  interconnected_health_and_socio_economic_outcomes         10         11
# 5                    medical_conditions_and_outcomes          8          7
# 6        pharmacological_and_cardiac_health_dynamics          6          6
#
#                                variable_descriptions  \
# 0  {'shivering': 'An involuntary muscular contrac...
# 1  {'rectal_varices': 'Abnormally enlarged and to...
# 2  {'property_damage': 'The impairment, destructi...
# 3  {'kidney_failure': 'A medical condition where ...
# 4  {'early_death': 'The occurrence of death at an...
# 5  {'early_death': 'The occurrence of mortality a...
# 6  {'palpitations': 'The subjective experience of...
#
#                                               priors  TP  FP  TN  FN  \
# 0  {(shivering, ascites), (shivering, hospital_ad...  10   0   7   4
# 1  {(heart_failure, lower_gastrointestinal_bleedi...   4   0   4   2
# 2  {(early_death, separation), (heart_failure, di...   9   0   8  19
# 3  {(heart_trouble, osteoporosis_associated_fract...  14   0  10  31
# 4  {(stagnant_economy, hospitalization), (clostri...  12   0  11  22
# 5  {(coronary_heart_disease, imbalanced_ph), (lam...  10   0   7  11
# 6  {(palpitations, appetite_suppression), (heart_...   7   0   6   2
#
#    Precision    Recall    F-beta  run_id
# 0        1.0  0.714286  0.984848       4
# 1        1.0  0.666667  0.981132       9
# 2        1.0  0.321429  0.924901       7
# 3        1.0  0.311111  0.921519       1
# 4        1.0  0.352941  0.934132       3
# 5        1.0  0.476190  0.959410       9
# 6        1.0  0.777778  0.989130       1

# %% [markdown]
# ### Average of the assessment results across multiple datasets

# %%
bnlearn_results_with_desc = pd.read_json("results/2025/llm/bnlearn_with_desc.json")
bnlearn_results_with_desc["dataset_type"] = "bnlearn"
bnlearn_results_with_desc["description_used"] = True

bnlearn_results_no_desc = pd.read_json("results/2025/llm/bnlearn_no_desc.json")
bnlearn_results_no_desc["dataset_type"] = "bnlearn"
bnlearn_results_no_desc["description_used"] = False

synthetic_results_with_desc = pd.read_json("results/2025/llm/synthetic_with_desc.json")
synthetic_results_with_desc["dataset_type"] = "synthetic"
synthetic_results_with_desc["description_used"] = True

synthetic_results_no_desc = pd.read_json("results/2025/llm/synthetic_no_desc.json")
synthetic_results_no_desc["dataset_type"] = "synthetic"
synthetic_results_no_desc["description_used"] = False

summary_df = pd.concat([
    bnlearn_results_with_desc,
    bnlearn_results_no_desc,
    synthetic_results_with_desc,
    synthetic_results_no_desc
], ignore_index=True).groupby(['dataset_type', 'description_used'])[
    ['Precision', 'Recall', "F-beta"]
].mean().reset_index()
summary_df.to_csv("results/2025/llm/prior_assessment.csv", index=False)
summary_df
# Out:
#   dataset_type  description_used  Precision    Recall    F-beta
# 0      bnlearn             False   0.878322  0.728327  0.865201
# 1      bnlearn              True   0.912024  0.671754  0.882731
# 2    synthetic             False   0.940081  0.382316  0.845814
# 3    synthetic              True   0.951584  0.358820  0.875679
